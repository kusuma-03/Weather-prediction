# %%
import pandas as pd
weather=pd.read_csv('/Users/anjan/Downloads/localwp.csv',index_col="DATE")

# %%
weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.660154
# ACSH       0.660154
# AWND       0.510584
# DAPR       0.999535
# FMTM       0.872645
# FRGT       0.999884
# MDPR       0.999535
# PGTM       0.504885
# PRCP       0.016341
# SNOW       0.340021
# SNWD       0.332810
# TAVG       0.881542
# TMAX       0.000640
# TMIN       0.000814
# TSUN       0.933066
# WDF1       0.660154
# WDF2       0.510526
# WDF5       0.515643
# WDFG       0.751861
# WSF1       0.660154
# WSF2       0.510468
# WSF5       0.515643
# WSFG       0.751861
# WT01       0.778844
# WT02       0.980112
# WT03       0.992789
# WT04       0.999767
# WT05       0.998372
# WT07       0.999884
# WT08       0.812922
# WT09       0.999884
# WT16       0.887299
# WT18       0.999826
# dtype: float64

# %%
core_weather = weather[["PRCP", "SNOW", "SNWD", "TMAX", "TMIN"]].copy()
core_weather.columns = ["precip", "snow", "snow_depth", "temp_max", "temp_min"]

# %%
core_weather.apply(pd.isnull).sum()
# Out:
# precip         281
# snow          5847
# snow_depth    5723
# temp_max        11
# temp_min        14
# dtype: int64

# %%
core_weather["snow"].value_counts()
# Out:
# 0.0    11348
# 1.0        1
# Name: snow, dtype: int64

# %%
core_weather["snow_depth"].value_counts()
# Out:
# 0.0    11473
# Name: snow_depth, dtype: int64

# %%
core_weather[pd.isnull(core_weather["precip"])]
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 1983-10-29     NaN   0.0         0.0      67.0      57.0
# 1983-10-30     NaN   0.0         0.0      70.0      63.0
# 1983-10-31     NaN   0.0         0.0      69.0      61.0
# 1983-11-12     NaN   0.0         0.0      63.0      55.0
# 1983-11-13     NaN   0.0         0.0      60.0      50.0
# 1983-11-14     NaN   0.0         0.0      61.0      45.0
# 1983-11-19     NaN   0.0         0.0      61.0      53.0
# 1983-11-20     NaN   0.0         0.0      58.0      46.0
# 1983-11-21     NaN   0.0         0.0      59.0      41.0
# 1983-12-03     NaN   0.0         0.0      58.0      54.0
# 1983-12-04     NaN   0.0         0.0      57.0      45.0
# 1983-12-05     NaN   0.0         0.0      55.0      42.0
# 1983-12-10     NaN   0.0         0.0      59.0      55.0
# 1983-12-11     NaN   0.0         0.0      59.0      51.0
# 1983-12-12     NaN   0.0         0.0      56.0      48.0
# ...

# %%
core_weather["precip"].value_counts() / core_weather.shape[0]
# Out:
# 0.00    0.811759
# 0.01    0.025704
# 0.02    0.011747
# 0.03    0.007153
# 0.04    0.006048
# 0.05    0.005815
# 0.06    0.005001
# 0.07    0.004536
# 0.08    0.004187
# 0.10    0.004129
# 0.14    0.003547
# 0.09    0.003373
# 0.13    0.003315
# 0.18    0.003024
# 0.11    0.002908
# 0.12    0.002733
# 0.15    0.002675
# 0.20    0.002617
# 0.19    0.002559
# 0.16    0.002384
# 0.22    0.002035
# 0.17    0.001977
# 0.26    0.001861
# 0.23    0.001861
# 0.29    0.001745
# 0.28    0.001686
# 0.24    0.001628
# 0.30    0.001512
# 0.25    0.001512
# 0.21    0.001396
#           ...
# 2.54    0.000058
# 2.01    0.000058
# 2.02    0.000058
# 1.98    0.000058
# 2.39    0.000058
# 1.59    0.000058
# 1.66    0.000058
# 1.93    0.000058
# 1.84    0.000058
# 2.14    0.000058
# 1.41    0.000058
# 1.61    0.000058
# 1.34    0.000058
# 1.77    0.000058
# 2.44    0.000058
# 1.92    0.000058
# 2.06    0.000058
# 1.17    0.000058
# 1.37    0.000058
# 2.56    0.000058
# 5.01    0.000058
# ...

# %%
core_weather["precip"] = core_weather["precip"].fillna(0)

# %%
core_weather.apply(pd.isnull).sum()
# Out:
# precip           0
# snow          5847
# snow_depth    5723
# temp_max        11
# temp_min        14
# dtype: int64

# %%
core_weather[pd.isnull(core_weather["temp_min"])]
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 2004-11-20     0.0   NaN         NaN       NaN       NaN
# 2011-12-21     0.0   0.0         0.0      61.0       NaN
# 2011-12-22     0.0   0.0         0.0      62.0       NaN
# 2011-12-23     0.0   0.0         0.0      56.0       NaN
# 2011-12-24     0.0   0.0         0.0      55.0       NaN
# 2011-12-25     0.0   0.0         0.0      54.0       NaN
# 2013-06-16     0.0   0.0         0.0       NaN       NaN
# 2020-08-29     0.0   NaN         NaN       NaN       NaN
# 2020-09-08     0.0   NaN         NaN       NaN       NaN
# 2020-09-09     0.0   NaN         NaN       NaN       NaN
# 2022-10-08     0.0   NaN         NaN       NaN       NaN
# 2022-10-09     0.0   NaN         NaN       NaN       NaN
# 2022-10-10     0.0   NaN         NaN      69.0       NaN
# 2022-10-11     0.0   NaN         NaN      66.0       NaN

# %%
core_weather.loc["2011-12-18":"2011-12-28"]
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 2011-12-18     0.0   0.0         0.0      52.0      33.0
# 2011-12-19     0.0   0.0         0.0      55.0      35.0
# 2011-12-20     0.0   0.0         0.0      61.0      35.0
# 2011-12-21     0.0   0.0         0.0      61.0       NaN
# 2011-12-22     0.0   0.0         0.0      62.0       NaN
# 2011-12-23     0.0   0.0         0.0      56.0       NaN
# 2011-12-24     0.0   0.0         0.0      55.0       NaN
# 2011-12-25     0.0   0.0         0.0      54.0       NaN
# 2011-12-26     0.0   0.0         0.0      50.0      32.0
# 2011-12-27     0.0   0.0         0.0      56.0      39.0
# 2011-12-28     0.0   0.0         0.0      57.0      38.0

# %%
core_weather = core_weather.fillna(method="ffill")

# %%
del core_weather["snow"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'snow'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-59cbc97ce6cf> in <module>()
#       1
# ----> 2 del core_weather["snow"]
#
# ...

# %%
del core_weather["snow_depth"]

# %%
core_weather.dtypes

# %%
core_weather.index

# %%
core_weather.index=pd.to_datetime(core_weather.index)

# %%
core_weather.index

# %% [raw]
# "jii"

# %%
core_weather.index

# %%
core_weather.index.year

# %%
core_weather[["temp_max", "temp_min"]].plot()

# %%
#the above graph depicts that there are some missing values between 1990 and 2006 so that is some thing we need to take care of

# %%
core_weather.index.year.value_counts().sort_index()
# Out:
# 1960    335
# 1961    365
# 1962    365
# 1963    365
# 1964    366
# 1965    365
# 1966    365
# 1967    365
# 1968    366
# 1969    365
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1983    184
# 1984    366
# 1985    365
# 1986    212
# 2000    365
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    365
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    365
# 2023     29
# Name: DATE, dtype: int64

# %%
core_weather["precip"].plot()

# %%
core_weather.groupby(core_weather.index.year).sum()["precip"]
# Out:
# DATE
# 1960    10.59
# 1961    13.87
# 1962    22.47
# 1963    19.11
# 1964    16.83
# 1965    16.32
# 1966    13.11
# 1967    23.98
# 1968    17.19
# 1969    25.70
# 1970    25.31
# 1971    10.61
# 1972    16.27
# 1973    29.37
# 1974    16.87
# 1975    17.54
# 1976     8.64
# 1977    11.70
# 1978    22.57
# 1979    23.79
# 1980    13.58
# 1983     7.13
# 1984    16.03
# 1985     8.50
# 1986     0.00
# 2000    21.09
# 2001    22.84
# 2002    19.12
# 2003    11.37
# 2004    12.97
# 2005    27.37
# 2006    22.79
# 2007    12.79
# 2008    13.86
# 2009    14.57
# 2010    22.67
# 2011    16.06
# 2012    22.93
# 2013     4.89
# 2014    19.62
# 2015     8.58
# 2016    19.77
# 2017    23.34
# 2018    16.82
# 2019    20.00
# 2020     6.42
# 2021    20.82
# 2022    15.38
# 2023     8.29
# Name: precip, dtype: float64

# %%
#the above code shows how many times it is rained in an year

# %%
#machine learning part
core_weather["target"]=core_weather.shift(-1)["temp_max"]

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target  month_max  month_day_max
# DATE
# 1960-02-01    0.81      62.0      51.0    59.0        NaN            NaN
# 1960-02-02    0.00      59.0      43.0    59.0        NaN            NaN
# 1960-02-03    0.20      59.0      47.0    60.0        NaN            NaN
# 1960-02-04    0.16      60.0      42.0    60.0        NaN            NaN
# 1960-02-05    0.67      60.0      53.0    63.0        NaN            NaN
# 1960-02-06    0.00      63.0      54.0    62.0        NaN            NaN
# 1960-02-07    0.06      62.0      55.0    60.0        NaN            NaN
# 1960-02-08    0.51      60.0      50.0    55.0        NaN            NaN
# 1960-02-09    0.36      55.0      48.0    60.0        NaN            NaN
# 1960-02-10    0.07      60.0      44.0    61.0        NaN            NaN
# 1960-02-11    0.00      61.0      40.0    61.0        NaN            NaN
# 1960-02-12    0.00      61.0      42.0    60.0        NaN            NaN
# ...

# %%
#predict tommorw weather using today data

# %%
core_weather=core_weather.iloc[:-1,:].copy()

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target  month_max  month_day_max
# DATE
# 1960-02-01    0.81      62.0      51.0    59.0        NaN            NaN
# 1960-02-02    0.00      59.0      43.0    59.0        NaN            NaN
# 1960-02-03    0.20      59.0      47.0    60.0        NaN            NaN
# 1960-02-04    0.16      60.0      42.0    60.0        NaN            NaN
# 1960-02-05    0.67      60.0      53.0    63.0        NaN            NaN
# 1960-02-06    0.00      63.0      54.0    62.0        NaN            NaN
# 1960-02-07    0.06      62.0      55.0    60.0        NaN            NaN
# 1960-02-08    0.51      60.0      50.0    55.0        NaN            NaN
# 1960-02-09    0.36      55.0      48.0    60.0        NaN            NaN
# 1960-02-10    0.07      60.0      44.0    61.0        NaN            NaN
# 1960-02-11    0.00      61.0      40.0    61.0        NaN            NaN
# 1960-02-12    0.00      61.0      42.0    60.0        NaN            NaN
# ...

# %%
from sklearn.linear_model import Ridge
reg=Ridge(alpha=.1)

# %%
predictors=["precip","temp_max","temp_min"]

# %%
train=core_weather.loc[:"2020-12-31"]

# %%
test=core_weather.loc["2021-01-01":]

# %%
reg.fit(train[predictors],train["target"])
# Out:
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
predictions=reg.predict(test[predictors])
print(predictions)
# Out:
# [59.80950512 59.31206287 58.5412344  61.53350286 59.44754932 59.02215774
#  60.16575932 61.96698593 59.27084762 61.43117923 60.71011843 62.50849423
#  65.39273746 68.99804148 65.57514076 68.81848898 70.62256639 78.36898115
#  69.17189238 66.11664906 58.90889181 58.36732101 59.80665432 57.24296416
#  58.54408521 53.54409984 57.19061911 58.09123242 57.61049657 60.88682012
#  64.12731754 64.27429313 62.17984968 59.98905762 62.33179254 64.85693076
#  67.37921817 66.65815737 60.16861012 61.78458263 62.14653843 60.20743548
#  63.58580924 64.10522202 59.7873471  62.51400835 60.52771512 65.75754406
#  64.31542245 61.89784855 64.82628282 64.85407995 73.32440631 78.37183195
#  72.06468801 65.75469326 63.41195834 64.49212415 69.72195309 67.55877067
#  65.03363245 63.95061584 64.13301915 65.06415539 61.20458488 62.15224004
#  63.40625674 62.51407085 56.3647198  60.57469448 63.95346665 61.24307432
#  62.4698798  60.34531182 59.08844431 59.62710182 60.38134887 64.30972085
# ...

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(test["target"],predictions)
# Out:
# 3.3779320226918528

# %%
combined=pd.concat([test["target"],pd.Series(predictions,index=test.index)],axis=1)

# %%
combined.columns=["actual","predictions"]

# %%
combined
# Out:
#             actual  predictions
# DATE
# 2021-01-01    57.0    59.809505
# 2021-01-02    56.0    59.312063
# 2021-01-03    62.0    58.541234
# 2021-01-04    59.0    61.533503
# 2021-01-05    59.0    59.447549
# 2021-01-06    59.0    59.022158
# 2021-01-07    61.0    60.165759
# 2021-01-08    60.0    61.966986
# 2021-01-09    62.0    59.270848
# 2021-01-10    61.0    61.431179
# 2021-01-11    62.0    60.710118
# 2021-01-12    66.0    62.508494
# 2021-01-13    71.0    65.392737
# 2021-01-14    67.0    68.998041
# 2021-01-15    71.0    65.575141
# 2021-01-16    74.0    68.818489
# 2021-01-17    83.0    70.622566
# 2021-01-18    69.0    78.368981
# 2021-01-19    68.0    69.171892
# 2021-01-20    59.0    66.116649
# 2021-01-21    57.0    58.908892
# 2021-01-22    59.0    58.367321
# 2021-01-23    56.0    59.806654
# 2021-01-24    57.0    57.242964
# 2021-01-25    54.0    58.544085
# 2021-01-26    56.0    53.544100
# 2021-01-27    57.0    57.190619
# 2021-01-28    57.0    58.091232
# ...

# %%
combined.plot()

# %%
#coefficient in regressionmodel

# %%
reg.coef_
# Out:
# array([-2.20955243,  0.72106081,  0.1795525 ])

# %%
def create_predictions(predictors,core_weather,reg):
    train=core_weather.loc[:"2020-12-31"]
    test=core_weather.loc["2021-01-01":]
    reg.fit(train[predictors],train["target"])
    predictions=reg.predict(test[predictors])
    error=mean_absolute_error(test["target"],predictions)
    combined=pd.concat([test["target"],pd.Series(predictions,index=test.index)],axis=1)
    combined.columns=["actual","predictions"]
    return error,combined

# %%
core_weather["month_max"]=core_weather["temp_max"].rolling(30).mean()

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target  month_max  month_day_max
# DATE
# 1960-02-01    0.81      62.0      51.0    59.0        NaN            NaN
# 1960-02-02    0.00      59.0      43.0    59.0        NaN            NaN
# 1960-02-03    0.20      59.0      47.0    60.0        NaN            NaN
# 1960-02-04    0.16      60.0      42.0    60.0        NaN            NaN
# 1960-02-05    0.67      60.0      53.0    63.0        NaN            NaN
# 1960-02-06    0.00      63.0      54.0    62.0        NaN            NaN
# 1960-02-07    0.06      62.0      55.0    60.0        NaN            NaN
# 1960-02-08    0.51      60.0      50.0    55.0        NaN            NaN
# 1960-02-09    0.36      55.0      48.0    60.0        NaN            NaN
# 1960-02-10    0.07      60.0      44.0    61.0        NaN            NaN
# 1960-02-11    0.00      61.0      40.0    61.0        NaN            NaN
# 1960-02-12    0.00      61.0      42.0    60.0        NaN            NaN
# ...

# %%
#rolling means look back 30 days before each day and fine rool mean and assing to the month max

# %%
core_weather["month_day_max"]=core_weather["month_max"]/core_weather["temp_max"]
